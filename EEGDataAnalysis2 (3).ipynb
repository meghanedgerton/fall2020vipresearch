# %%
import sys
# !{sys.executable} -m pip install plotly==4.12.0
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import scipy
import pandas as pd
import os
import random
import matplotlib
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
from plotly import tools
from tqdm import tqdm

init_notebook_mode(connected=True)
seed = 132
random.seed = seed
# Out:
# ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Subject 1 (Meghan)

# %%
data1 = np.genfromtxt('/Users/megha/Desktop/Subject1Part1.txt',
                    skip_header=1,
                    delimiter=',')

data2 = np.genfromtxt('/Users/megha/Desktop/Subject1Part2.txt',
                    skip_header=1,
                    delimiter=',')

data3 = np.genfromtxt('/Users/megha/Desktop/Subject1Part3.txt',
                    skip_header=1,
                    delimiter=',')

Sample1 = pd.DataFrame(data1, columns = ['Sample Index','EXG Channel 0','EXG Channel 1', 'EXG Channel 2','EXG Channel 3','Accel Channel 0','Accel Channel 1','Accel Channel 2','Other','Other','Other','Other','Other','Timestamp','Timestamp Formatted'])
Sample2 = pd.DataFrame(data2, columns = ['Sample Index','EXG Channel 0','EXG Channel 1', 'EXG Channel 2','EXG Channel 3','Accel Channel 0','Accel Channel 1','Accel Channel 2','Other','Other','Other','Other','Other','Timestamp','Timestamp Formatted'])
Sample3 = pd.DataFrame(data3, columns = ['Sample Index','EXG Channel 0','EXG Channel 1', 'EXG Channel 2','EXG Channel 3','Accel Channel 0','Accel Channel 1','Accel Channel 2','Other','Other','Other','Other','Other','Timestamp','Timestamp Formatted'])

Samp1 = Sample1[['Sample Index','EXG Channel 0','EXG Channel 1','EXG Channel 2','EXG Channel 3']]
Samp1 = Samp1.iloc[0:16,:]
Samp1 = Samp1.style.hide_index()
Samp1 = Samp1.set_table_styles([dict(selector = 'th', props = [('text-align','center')])])
#Samp1

Samp2 = Sample2[['Sample Index','EXG Channel 0','EXG Channel 1','EXG Channel 2','EXG Channel 3']]
Samp2 = Samp2.iloc[0:16,:]
Samp2 = Samp2.style.hide_index()
Samp2 = Samp2.set_table_styles([dict(selector = 'th', props = [('text-align','center')])])
#Samp2

Samp3 = Sample3[['Sample Index','EXG Channel 0','EXG Channel 1','EXG Channel 2','EXG Channel 3']]
Samp3 = Samp3.iloc[0:16,:]
Samp3 = Samp3.style.hide_index()
Samp3 = Samp3.set_table_styles([dict(selector = 'th', props = [('text-align','center')])])
#Samp3

# %% [markdown]
# ### Visualization

# %%
samp1time = Sample1['Timestamp']
channel0 = Sample1['EXG Channel 0']
channel1 = Sample1['EXG Channel 1']
channel2 = Sample1['EXG Channel 2']
channel3 = Sample1['EXG Channel 3']

plt.figure()
plt.plot(samp1time,channel0)

plt.plot(samp1time,channel1)

plt.plot(samp1time,channel2)

plt.plot(samp1time,channel3)

plt.ylabel('Voltage Reading in mV')
plt.xlabel('Timestamp')
plt.title('Subject 1 Sample 1')
plt.legend(loc = 'upper right',bbox_to_anchor=(0.5, -0.15), ncol= 2)

# %%
samp2time = Sample2['Timestamp']
channel0 = Sample2['EXG Channel 0']
channel1 = Sample2['EXG Channel 1']
channel2 = Sample2['EXG Channel 2']
channel3 = Sample2['EXG Channel 3']

plt.figure()
plt.plot(samp2time,channel0)

plt.plot(samp2time,channel1)

plt.plot(samp2time,channel2)

plt.plot(samp2time,channel3)

plt.ylabel('Voltage Reading in mV')
plt.xlabel('Timestamp')
plt.title('Subject 1 Sample 2')
plt.legend(loc = 'upper right',bbox_to_anchor=(0.5, -0.15), ncol= 2)

# %%
samp3time = Sample3['Timestamp']
channel0 = Sample3['EXG Channel 0']
channel1 = Sample3['EXG Channel 1']
channel2 = Sample3['EXG Channel 2']
channel3 = Sample3['EXG Channel 3']

plt.figure()
plt.plot(samp3time,channel0)

plt.plot(samp3time,channel1)

plt.plot(samp3time,channel2)

plt.plot(samp3time,channel3)

plt.ylabel('Voltage Reading in mV')
plt.xlabel('Timestamp')
plt.title('Subject 1 Sample 3')
plt.legend(loc = 'upper right',bbox_to_anchor=(0.5, -0.15), ncol= 2)

# %% [markdown]
# ### Subject 2 (Gabe)

# %%
data4 = np.genfromtxt('/Users/megha/Desktop/Subject2Part1.txt',
                    skip_header=1,
                    delimiter=',')

data5 = np.genfromtxt('/Users/megha/Desktop/Subject2Part2.txt',
                    skip_header=1,
                    delimiter=',')

data6 = np.genfromtxt('/Users/megha/Desktop/Subject2Part3.txt',
                    skip_header=1,
                    delimiter=',')

Sample4 = pd.DataFrame(data4, columns = ['Sample Index','EXG Channel 0','EXG Channel 1', 'EXG Channel 2','EXG Channel 3','Accel Channel 0','Accel Channel 1','Accel Channel 2','Other','Other','Other','Other','Other','Timestamp','Timestamp Formatted'])
Sample5 = pd.DataFrame(data5, columns = ['Sample Index','EXG Channel 0','EXG Channel 1', 'EXG Channel 2','EXG Channel 3','Accel Channel 0','Accel Channel 1','Accel Channel 2','Other','Other','Other','Other','Other','Timestamp','Timestamp Formatted'])
Sample6 = pd.DataFrame(data6, columns = ['Sample Index','EXG Channel 0','EXG Channel 1', 'EXG Channel 2','EXG Channel 3','Accel Channel 0','Accel Channel 1','Accel Channel 2','Other','Other','Other','Other','Other','Timestamp','Timestamp Formatted'])

Samp4 = Sample4[['Sample Index','EXG Channel 0','EXG Channel 1','EXG Channel 2','EXG Channel 3']]
Samp4 = Samp4.iloc[0:16,:]
Samp4 = Samp4.style.hide_index()
Samp4 = Samp4.set_table_styles([dict(selector = 'th', props = [('text-align','center')])])
#Samp4

Samp5 = Sample5[['Sample Index','EXG Channel 0','EXG Channel 1','EXG Channel 2','EXG Channel 3']]
Samp5 = Samp5.iloc[0:16,:]
Samp5 = Samp5.style.hide_index()
Samp5 = Samp5.set_table_styles([dict(selector = 'th', props = [('text-align','center')])])
#Samp5

Samp6 = Sample6[['Sample Index','EXG Channel 0','EXG Channel 1','EXG Channel 2','EXG Channel 3']]
Samp6 = Samp6.iloc[0:16,:]
Samp6 = Samp6.style.hide_index()
Samp6 = Samp6.set_table_styles([dict(selector = 'th', props = [('text-align','center')])])
#Samp6

# %% [markdown]
# ### Visualization

# %%
samp4time = Sample4['Timestamp']
channel0 = Sample4['EXG Channel 0']
channel1 = Sample4['EXG Channel 1']
channel2 = Sample4['EXG Channel 2']
channel3 = Sample4['EXG Channel 3']

plt.figure()
plt.plot(samp4time,channel0)

plt.plot(samp4time,channel1)

plt.plot(samp4time,channel2)

plt.plot(samp4time,channel3)
plt.ylabel('Voltage Reading in mV')
plt.xlabel('Timestamp')
plt.title('Subject 2 Sample 1')
plt.legend(loc = 'upper right',bbox_to_anchor=(0.5, -0.15), ncol= 2)

# %%
samp5time = Sample5['Timestamp']
channel0 = Sample5['EXG Channel 0']
channel1 = Sample5['EXG Channel 1']
channel2 = Sample5['EXG Channel 2']
channel3 = Sample5['EXG Channel 3']

plt.figure()
plt.plot(samp5time,channel0)

plt.plot(samp5time,channel1)

plt.plot(samp5time,channel2)

plt.plot(samp5time,channel3)

plt.ylabel('Voltage Reading in mV')
plt.xlabel('Timestamp')
plt.title('Subject 2 Sample 2')
plt.legend(loc = 'upper right',bbox_to_anchor=(0.5, -0.15), ncol= 2)

# %%
samp6time = Sample6['Timestamp']
channel0 = Sample6['EXG Channel 0']
channel1 = Sample6['EXG Channel 1']
channel2 = Sample6['EXG Channel 2']
channel3 = Sample6['EXG Channel 3']

plt.figure()
plt.plot(samp6time,channel0)

plt.plot(samp6time,channel1)

plt.plot(samp6time,channel2)

plt.plot(samp6time,channel3)

plt.ylabel('Voltage Reading in mV')
plt.xlabel('Timestamp')
plt.title('Subject 2 Sample 3')
plt.legend(loc = 'upper right',bbox_to_anchor=(0.5, -0.15), ncol= 2)
